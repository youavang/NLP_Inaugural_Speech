# %% [markdown]
# <a href="https://colab.research.google.com/github/youavang/NLP_Inaugural_Speech/blob/main/NLP_Text_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation

# %% [markdown]
# In this notebook we are going to generate sentences using Markov chains method. Markov chains can be used for very basic text generation. For this method, we can assume that the next word is dependent on the previous word.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# We are going to generate text in the style of President Barack Obama. The first step is to extract the text from his speech.

# %%
# Mount to Google Drive to access saved files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('/content/drive/MyDrive/pickle/corpus.pkl')
data
# Out:
#                                                 transcript       full_name
# bush     Thank you, all. Chief Justice Rehnquist, Presi...  George W. Bush
# clinton  My fellow citizens, today we celebrate the mys...    Bill Clinton
# obama    My fellow citizens, I stand here today humbled...    Barack Obama
# trump    Chief Justice Roberts, President Carter, Presi...    Donald Trump

# %%
# Extract only President Obama's text
obama_text = data.transcript.loc['obama']
obama_text
# Out:
# 'My fellow citizens, I stand here today humbled by the task before us, grateful for the trust you have bestowed, mindful of the sacrifices borne by our ancestors. I thank President Bush for his service to our Nation, as well as the generosity and cooperation he has shown throughout this transition. Forty-four Americans have now taken the Presidential oath. The words have been spoken during rising tides of prosperity and the still waters of peace. Yet every so often, the oath is taken amidst gathering clouds and raging storms. At these moments, America has carried on not simply because of the skill or vision of those in high office, but because we the people have remained faithful to the ideals of our forebears and true to our founding documents. So it has been; so it must be with this generation of Americans. That we are in the midst of crisis is now well understood. Our Nation is at war against a far-reaching network of violence and hatred. Our economy is badly weakened, a consequence of greed and irresponsibility on the part of some, but also our collective failure to make hard choices and prepare the Nation for a new age. Homes have been lost, jobs shed, businesses shuttered. Our health care is too costly. Our schools fail too many. And each day brings further evidence that the ways we use energy strengthen our adversaries and threaten our planet. These are the indicators of crisis, subject to data and statistics. Less measurable but no less profound is a sapping of confidence across our land, a nagging fear that America\'s decline is inevitable, that the next generation must lower its sights. Today I say to you that the challenges we face are real. They are serious, and they are many. They will not be met easily or in a short span of time. But know this, America: They will be met. On this day, we gather because we have chosen hope over fear, unity of purpose over conflict and discord. On this day, we come to proclaim an end to the petty grievances and false promises, the recriminations and worn-out dogmas that for far too long have strangled our politics. We remain a young nation, but in the words of Scripture, the time has come to set aside childish things. The time has come to reaffirm our enduring spirit, to choose our better history, to carry forward that precious gift, that noble idea passed on from generation to generation: the God-given promise that all are equal, all are free, and all deserve a chance to pursue their full measure of happiness. In reaffirming the greatness of our Nation, we understand that greatness is never a given. It must be earned. Our journey has never been one of shortcuts or settling for less. It has not been the path for the fainthearted, for those who prefer leisure over work or seek only the pleasures of riches and fame. Rather, it has been the risk-takers, the doers, the makers of things--some celebrated, but more often men and women obscure in their labor--who have carried us up the long, rugged path toward prosperity and freedom. For us, they packed up their few worldly possessions and traveled across oceans in search of a new life. For us, they toiled in sweatshops and settled the West, endured the lash of the whip, and plowed the hard Earth. For us, they fought and died in places like Concord and Gettysburg, Normandy and Khe Sanh. Time and again, these men and women struggled and sacrificed and worked \'til their hands were raw so that we might live a better life. They saw America as bigger than the sum of our individual ambitions, greater than all the differences of birth or wealth or faction. This is the journey we continue today. We remain the most prosperous, powerful nation on Earth. Our workers are no less productive than when this crisis began. Our minds are no less inventive. Our goods and services no less needed than they were last week or last month or last year. Our capacity remains undiminished. But our time of standing pat, of protecting narrow interests and putting off u ...

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# Build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for President Obama's speech.
obama_dict = markov_chain(obama_text)
obama_dict
# Out:
# {'My': ['fellow'],
#  'fellow': ['citizens,'],
#  'citizens,': ['I'],
#  'I': ['stand', 'thank', 'say'],
#  'stand': ['here', 'before'],
#  'here': ['today'],
#  'today': ['humbled', 'is'],
#  'humbled': ['by'],
#  'by': ['the',
#   'our',
#   'the',
#   'these',
#   'inducing',
#   'every',
#   'dying',
#   'our',
#   'the',
#   'Gerhard'],
#  'the': ['task',
#   'trust',
#   'sacrifices',
#   'generosity',
#   'Presidential',
#   'still',
#   'oath',
#   'skill',
#   'people',
#   'ideals',
#   'midst',
#   'part',
#   'Nation',
#   'ways',
#   'indicators',
#   'next',
#   'challenges',
#   'petty',
#   'recriminations',
#   'words',
#   'time',
#   'God-given',
#   'greatness',
#   'path',
#   'fainthearted,',
#   'pleasures',
#   'risk-takers,',
#   'doers,',
#   'makers',
#   'long,',
#   'West,',
#   'lash',
#   'whip,',
#   'hard',
#   'sum',
#   'differences',
#   'journey',
#   'most',
#   'work',
#   'economy',
#   'roads',
#   'electric',
#   'sun',
#   'winds',
#   'soil',
#   'demands',
#   'scale',
#   'cynics',
#   'ground',
#   'stale',
#   'answer',
#   'answer',
#   "public's",
#   'light',
#   'vital',
#   'question',
#   'market',
#   'market',
#   'prosperous.',
#   'size',
#   'reach',
#   'surest',
#   'choice',
#   'rule',
#   'rights',
#   'blood',
#   'world,',
#   'other',
#   'grandest',
#   'small',
#   'justness',
#   'force',
#   'tempering',
#   'keepers',
#   'nuclear',
#   'specter',
#   'bitter',
#   'old',
#   'lines',
#   'world',
#   'Muslim',
#   'globe',
#   'West,',
#   'silencing',
#   'wrong',
#   'people',
#   "world's",
#   'world',
#   'road',
#   'fallen',
#   'ages.',
#   'spirit',
#   'faith',
#   'American',
#   'kindness',
#   'levees',
#   'selflessness',
#   "firefighter's",
#   'quiet',
#   'part',
#   'world.',
#   'knowledge',
#   'spirit,',
#   'price',
#   'promise',
#   'source',
#   'knowledge',
#   'meaning',
#   'year',
#   'coldest',
#   'shores',
#   'outcome',
#   'Father',
#   'people:',
#   'future',
#   'depth',
#   'city',
#   'country,',
#   'face',
#   'icy',
#   'horizon',
#   'United',
#   'West',
#   'U.S.',
#   'address,',
#   'oath',
#   'Office',
#   'Press'],
#  'task': ['before'],
#  'before': ['us,', 'us', 'us,', 'you'],
#  'us,': ['grateful', 'they', 'they', 'they', 'nor', 'and', 'we', 'we'],
#  'grateful': ['for'],
#  'for': ['the',
#   'his',
#   'a',
#   'far',
#   'less.',
#   'the',
#   'those',
#   'action,',
#   'growth.',
#   'they',
#   'so',
#   'good',
#   'our',
#   "expedience's",
#   'our',
#   'those',
#   'the'],
#  'trust': ['you', 'between'],
#  'you': ['have',
#   'that',
#   'now',
#   'on',
#   'can',
#   'destroy.',
#   'are',
#   'are',
#   'to',
#   'to'],
#  'have': ['bestowed,',
#   'now',
#   'been',
#   'remained',
#   'been',
#   'chosen',
#   'strangled',
#   'carried',
#   'forgotten',
#   'consumed',
#   'tasted',
#   'something',
#   'been',
#   'duties',
#   'been',
#   'traveled.'],
#  'bestowed,': ['mindful'],
#  'mindful': ['of'],
#  'of': ['the',
#   'prosperity',
#   'peace.',
#   'the',
#   'those',
#   'our',
#   'Americans.',
#   'crisis',
#   'violence',
#   'greed',
#   'some,',
#   'crisis,',
#   'confidence',
#   'time.',
#   'purpose',
#   'Scripture,',
#   'happiness.',
#   'our',
#   'shortcuts',
#   'riches',
#   'things--some',
#   'a',
#   'the',
#   'our',
#   'birth',
#   'standing',
#   'protecting',
#   'remaking',
#   'the',
#   'a',
#   'our',
#   'us',
#   'day,',
#   'control.',
#   'our',
#   'our',
#   'our',
#   'charity,',
#   'law',
#   'man,',
#   'generations.',
#   'each',
#   'peace',
#   'our',
#   'our',
#   'humility',
#   'this',
#   'a',
#   'life,',
#   'Christians',
#   'this',
#   'civil',
#   'tribe',
#   'peace.',
#   'dissent,',
#   'history,',
#   'poor',
#   'our',
#   'service,',
#   'the',
#   'workers',
#   'progress',
#   'us',
#   'responsibility,',
#   'every',
#   'our',
#   'citizenship.',
#   'our',
#   'our',
#   'every',
#   'who',
#   "America's",
#   'months,',
#   'patriots',
#   'an',
#   'our',
#   'our',
#   'winter,',
#   'our',
#   'our',
#   'freedom',
#   'America.',
#   'the',
#   'office.',
#   'the'],
#  'sacrifices': ['borne'],
#  'borne': ['by'],
#  'our': ['ancestors.',
#   'Nation,',
#   'forebears',
#   'founding',
#   'collective',
#   'adversaries',
#   'planet.',
#   'land,',
#   'politics.',
#   'enduring',
#   'better',
#   'Nation,',
#   'individual',
#   'time',
#   'commerce',
#   'cars',
#   'factories.',
#   'schools',
#   'ambitions,',
#   'system',
#   'Government',
#   'business',
#   'economy',
#   'gross',
#   'prosperity,',
#   'ability',
#   'common',
#   'common',
#   'safety',
#   'ideals.',
#   'power',
#   'power',
#   'cause,',
#   'example,',
#   'way',
#   'spirit',
#   'patchwork',
#   'common',
#   'borders,',
#   'liberty,',
#   'darkest',
#   'fate.',
#   'success',
#   'history.',
#   'Nation,',
#   'character,',
#   'all',
#   'confidence,',
#   'liberty',
#   'creed;',
#   'Revolution',
#   'Nation',
#   'common',
#   'hardship,',
#   "children's"],
#  'ancestors.': ['I'],
#  'thank': ['President'],
#  'President': ['Bush', 'spoke'],
#  'Bush': ['for'],
#  'his': ['service'],
#  'service': ['to'],
#  'to': ['our',
#   'the',
#   'our',
#   'make',
#   'data',
#   'you',
#   'proclaim',
#   'the',
#   'set',
#   'reaffirm',
#   'choose',
#   'carry',
#   'generation:',
#   'pursue',
#   'be',
#   'create',
#   'lay',
#   'its',
#   'raise',
#   'fuel',
#   'meet',
#   'common',
#   'courage.',
#   'understand',
#   'move',
#   'account',
#   'spend',
#   'generate',
#   'extend',
#   'every',
#   'our',
#   'assure',
#   'all',
#   'the',
#   'lead',
#   'do',
#   'responsibly',
#   'its',
#   'lessen',
#   'advance',
#   'you',
#   'sow',
#   'power',
#   'unclench',
#   'work',
#   'make',
#   'nourish',
#   'those',
#   'suffering',
#   'effect,',
#   'tell',
#   'find',
#   'take',
#   'storm',
#   'nurture',
#   'these',
#   'ourselves,',
#   'the',
#   'a',
#   'shape',
#   'take',
#   'the',
#   'the',
#   'meet',
#   'let',
#   'future',
#   'the'],
#  'Nation,': ['as', 'we', 'and'],
#  'as': ['well',
#   'the',
#   'bigger',
#   'false',
#   'we',
#   'the',
#   'the',
#   'much',
#   'Government'],
#  'well': ['as', 'understood.'],
#  'generosity': ['and'],
#  'and': ['cooperation',
#   'the',
#   'raging',
#   'true',
#   'hatred.',
#   'irresponsibility',
#   'prepare',
#   'threaten',
#   'statistics.',
#   'they',
#   'discord.',
#   'false',
#   'worn-out',
#   'all',
#   'fame.',
#   'women',
#   'freedom.',
#   'traveled',
#   'settled',
#   'plowed',
#   'died',
#   'Gettysburg,',
#   'Khe',
#   'again,',
#   'women',
#   'sacrificed',
#   'worked',
#   'services',
#   'putting',
#   'begin',
#   'swift,',
#   'we',
#   'bridges,',
#   'digital',
#   'bind',
#   'wield',
#   'lower',
#   'the',
#   'the',
#   'run',
#   'colleges',
#   'universities',
#   'women',
#   'necessity',
#   'do',
#   'their',
#   'expand',
#   'our',
#   'the',
#   'we',
#   'governments',
#   'every',
#   'child',
#   'dignity,',
#   'we',
#   'communism',
#   'tanks',
#   'enduring',
#   'restraint.',
#   'understanding',
#   'forge',
#   'former',
#   'roll',
#   'slaughtering',
#   'cannot',
#   'we',
#   'Muslims,',
#   'Hindus',
#   'nonbelievers.',
#   'culture,',
#   'segregation',
#   'emerged',
#   'more',
#   'that',
#   'mutual',
#   'deceit',
#   'the',
#   'let',
#   'feed',
#   'we',
#   'distant',
#   'must',
#   'determination',
#   'hard',
#   'fair',
#   'curiosity,',
#   'patriotism--these',
#   'the',
#   'the',
#   'our',
#   'women',
#   'children',
#   'every',
#   'why',
#   'how',
#   'virtue',
#   'the',
#   'virtue,',
#   'endure',
#   "God's",
#   'delivered',
#   'God',
#   'John'],
#  'cooperation': ['he', 'and'],
#  'he': ['has'],
#  'has': ['shown',
#   'carried',
#   'been;',
#   'come',
#   'come',
#   'never',
#   'not',
#   'been',
#   'surely',
#   'already',
#   'shifted',
#   'reminded',
#   'always',
#   'changed,'],
#  'shown': ['throughout'],
#  'throughout': ['this', 'our'],
#  'this': ['transition.',
#   'generation',
#   'day,',
#   'day,',
#   'crisis',
#   'we',
#   'we',
#   'country',
#   'crisis',
#   'legacy.',
#   'Earth.',
#   'very',
#   'moment,',
#   'spirit',
#   'Nation',
#   'magnificent',
#   'day',
#   'winter',
#   'journey'],
#  'transition.': ['Forty-four'],
#  'Forty-four': ['Americans'],
#  'Americans': ['have', 'who,'],
#  'now': ['taken', 'well', 'that', 'is', 'stand'],
#  'taken': ['the', 'amidst'],
#  'Presidential': ['oath.'],
#  'oath.': ['The', 'So'],
#  'The': ['words',
#   'time',
#   'state',
#   'question',
#   'Nation',
#   'success',
#   'instruments',
#   'Capital',
#   'enemy',
#   'snow',
#   'President',
#   'transcript',
#   'American'],
#  'words': ['have', 'of', 'be'],
#  'been': ['spoken', 'lost,', 'one', 'the', 'the', 'the', 'served'],
#  'spoken': ['during'],
#  'during': ['rising'],
#  'rising': ['tides'],
#  'tides': ['of'],
#  'prosperity': ['and', 'and'],
#  'still': ['waters', 'light'],
#  'waters': ['of', 'flow,'],
#  'peace.': ['Yet', 'To'],
#  'Yet': ['every'],
#  'every': ['so',
#   'willing',
#   'man,',
#   'language',
#   'end',
#   'American',
#   'race',
#   'faith'],
#  'so': ['often,', 'it', 'that', 'long', 'to', 'satisfying', 'defining'],
#  'often,': ['the'],
#  'oath': ['is', 'of'],
#  'is': ['taken',
#   'now',
#   'at',
#   'badly',
#   'too',
#   'a',
#   'inevitable,',
#   'never',
#   'the',
#   'work',
#   'joined',
#   'that',
#   'not',
#   'too',
#   'dignified.',
#   'yes,',
#   'no,',
#   'the',
#   'a',
#   'unmatched.',
#   'the',
#   'a',
#   'stronger',
#   'a',
#   'precisely',
#   'ultimately',
#   'the',
#   'the',
#   'demanded',
#   'a',
#   'required',
#   'a',
#   'nothing',
#   'the',
#   'the',
#   'the'],
#  'amidst': ['gathering'],
#  'gathering': ['clouds'],
#  'clouds': ['and'],
#  'raging': ['storms.'],
#  'storms.': ['At'],
#  'At': ['these', 'a'],
#  'these': ['moments,', 'men', 'principles', 'truths.', 'words', 'timeless'],
#  'moments,': ['America'],
#  'America': ['has', 'as', 'is', 'must'],
#  'carried': ['on', 'us', 'forth'],
#  'on': ['not',
#   'the',
#   'from',
#   'Earth.',
#   'the',
#   'the',
#   'our',
#   'mutual',
#   'the',
#   'what',
#   'the',
#   'the',
#   'us',
#   'the',
#   'the',
#   'January'],
#  'not': ['simply',
#   'be',
#   'been',
#   'only',
#   'whether',
#   'just',
#   'out',
#   'give',
#   'just',
#   'apologize',
#   'a',
#   'what',
#   'only',
#   'grudgingly',
#   'have',
#   'turn'],
#  'simply': ['because'],
#  'because': ['of', 'we', 'we', 'only', 'it', 'we', 'they', 'they'],
#  'skill': ['or'],
#  'or': ['vision',
#   'in',
#   'settling',
#   'seek',
#   'wealth',
#   'faction.',
#   'last',
#   'last',
#   'too',
#   'ill.',
#   'blame'],
#  'vision': ['of'],
#  'those': ['in',
#   'who',
#   'of',
#   'new',
#   'who',
#   'leaders',
#   'who',
#   'nations',
#   'brave',
#   'values'],
#  'in': ['high',
#   'the',
#   'a',
#   'the',
#   'their',
#   'search',
#   'sweatshops',
#   'places',
#   'the',
#   'Afghanistan.',
#   'its',
#   'ushering',
#   'a',
#   'Arlington',
#   'something',
#   'a',
#   'the',
#   'celebration',
#   'the',
#   'doubt,',
#   'the',
#   'the',
#   'this'],
#  'high': ['office,'],
#  'office,': ['but'],
#  'but': ['because',
#   'also',
#   'no',
#   'in',
#   'more',
#   'to',
#   'whether',
#   'on',
#   'because',
#   'with',
#   'believe',
#   'that',
#   'because',
#   'also',
#   'hope'],
#  'we': ['the',
#   'are',
#   'use',
#   'face',
#   'gather',
#   'have',
#   'come',
#   'understand',
#   'might',
#   'continue',
#   'must',
#   'look,',
#   'will',
#   'will',
#   'can',
#   'will',
#   'ask',
#   'intend',
#   'restore',
#   'reject',
#   'can',
#   'will',
#   'are',
#   'please.',
#   'can',
#   'will',
#   'waver',
#   'say',
#   'will',
#   'know',
#   'have',
#   'cannot',
#   'seek',
#   'will',
#   'pledge',
#   'say',
#   'can',
#   'consume',
#   'must',
#   'consider',
#   'remember',
#   'meet',
#   'have',
#   'do',
#   'are',
#   'have',
#   'were',
#   'refused',
#   'did',
#   'falter.',
#   'carried'],
#  'people': ['have', 'and', 'and', 'will', 'of', 'upon'],
#  'remained': ['faithful'],
#  'faithful': ['to'],
#  'ideals': ['of', 'still'],
#  'forebears': ['and'],
#  'true': ['to'],
#  'founding': ['documents.'],
#  'documents.': ['So'],
#  'So': ['it', 'let'],
#  'it': ['has',
#   'must',
#   'has',
#   'works;',
#   'helps',
#   'favors',
#   'is',
#   'entitle',
#   'is',
#   'is',
#   'be',
#   'be',
#   'safely'],
#  'been;': ['so'],
#  'must': ['be', 'lower', 'be', 'pick', 'play', 'change', 'inhabit', 'do,'],
#  'be': ['with',
#   'met',
#   'met.',
#   'earned.',
#   'done.',
#   'held',
#   'broken.',
#   'new.',
#   'new.',
#   'read',
#   'told',
#   'said'],
#  'with': ['this',
#   'perils',
#   'missiles',
#   'sturdy',
#   'it.',
#   'humble',
#   'smoke,',
#   'which',
#   'remembrance',
#   'blood.',
#   'eyes'],
#  'generation': ['of', 'must', 'to'],
#  'Americans.': ['That'],
#  'That': ['we'],
#  'are': ['in',
#   'the',
#   'real.',
#   'serious,',
#   'many.',
#   'equal,',
#   'free,',
#   'no',
#   'no',
#   'some',
#   'short,',
#   'watching',
#   'ready',
#   'the',
#   'a',
#   'shaped',
#   'on',
#   'willing',
#   'guardians',
#   'old.',
#   'true.',
#   'and'],
#  'midst': ['of'],
#  'crisis': ['is', 'began.', 'has'],
#  'understood.': ['Our'],
#  'Our': ['Nation',
#   'economy',
#   'health',
#   'schools',
#   'journey',
#   'workers',
#   'minds',
#   'goods',
#   'capacity',
#   'Founding',
#   'security',
#   'challenges'],
#  'Nation': ['is', 'for', 'cannot', 'relies.', 'ordered'],
#  'at': ['war', 'a', 'this', 'this', 'a', 'one', 'approximately', 'the'],
#  'war': ['against', 'and'],
#  'against': ['a'],
#  'a': ['far-reaching',
#   'consequence',
#   'new',
#   'sapping',
#   'nagging',
#   'short',
#   'young',
#   'chance',
#   'given.',
#   'new',
#   'better',
#   'new',
#   'new',
#   'decent',
#   'retirement',
#   'people',
#   'force',
#   'watchful',
#   'charter',
#   'charter',
#   'friend',
#   'future',
#   'hard-earned',
#   'warming',
#   'strength,',
#   'weakness.',
#   'nation',
#   'new',
#   'new',
#   'hand',
#   'willingness',
#   'moment',
#   'generation,',
#   'stranger',
#   'friend',
#   'stairway',
#   "parent's",
#   'child,',
#   'return',
#   'new',
#   'recognition',
#   'difficult',
#   'man',
#   'local',
#   'most',
#   'small',
#   'moment'],
#  'far-reaching': ['network'],
#  'network': ['of'],
#  'violence': ['and'],
#  'hatred.': ['Our'],
#  'economy': ['is', 'calls', 'has'],
#  'badly': ['weakened,'],
#  'weakened,': ['a'],
#  'consequence': ['of'],
#  'greed': ['and'],
#  'irresponsibility': ['on'],
#  'part': ['of', 'of'],
#  'some,': ['but'],
#  'also': ['our', 'a'],
#  'collective': ['failure'],
#  'failure': ['to'],
#  'make': ['hard', 'your'],
#  'hard': ['choices', 'Earth.', 'work,'],
#  'choices': ['and'],
#  'prepare': ['the'],
#  'new': ['age.',
#   'life.',
#   'jobs',
#   'foundation',
#   'age.',
#   'threats',
#   'era',
#   'way',
#   'era'],
#  'age.': ['Homes', 'All'],
#  'Homes': ['have'],
#  'lost,': ['jobs'],
#  'jobs': ['shed,', 'but', 'at'],
#  'shed,': ['businesses'],
#  'businesses': ['shuttered.'],
#  'shuttered.': ['Our'],
#  'health': ['care', "care's"],
#  'care': ['is', 'they'],
#  'too': ['costly.', 'many.', 'long', 'many', 'big', 'small,'],
#  'costly.': ['Our'],
#  'schools': ['fail', 'and'],
#  'fail': ['too', 'to'],
#  'many.': ['And', 'They'],
#  'And': ['each', 'we', 'those', 'so', 'for', 'because', 'to', 'yet', 'with'],
#  'each': ['day', 'nation'],
#  'day': ['brings', 'with'],
#  'brings': ['further'],
#  'further': ['evidence'],
#  'evidence': ['that'],
#  'that': ['the',
#   "America's",
#   'the',
#   'the',
#   'for',
#   'precious',
#   'noble',
#   'all',
#   'greatness',
#   'we',
#   'time',
#   'feed',
#   'our',
#   'the',
#   'the',
#   'have',
#   'is',
#   'without',
#   'we',
#   'America',
#   'earlier',
#   'our',
#   'our',
#   'demand',
#   'our',
#   'our',
#   'dark',
#   'the',
#   'the',
#   'as',
#   'America',
#   'your',
#   'you',
#   'we',
#   'enjoy',
#   'unfolds',
#   'will',
#   'must',
#   'finally',
#   'we',
#   'we',
#   'there',
#   'God',
#   'in',
#   'the',
#   'when',
#   'we',
#   'great'],
#  'ways': ['we'],
#  'use': ['energy'],
#  'energy': ['strengthen'],
#  'strengthen': ['our'],
#  'adversaries': ['and'],
#  'threaten': ['our'],
#  'planet.': ['These', 'We'],
#  'These': ['are', 'things'],
#  'indicators': ['of'],
#  'crisis,': ['subject'],
#  'subject': ['to'],
#  'data': ['and'],
#  'statistics.': ['Less'],
#  'Less': ['measurable'],
#  'measurable': ['but'],
#  'no': ['less', 'less', 'less', 'less', 'longer', 'longer'],
#  'less': ['profound', 'productive', 'inventive.', 'needed', 'than'],
#  'profound': ['is'],
#  'sapping': ['of'],
#  'confidence': ['across'],
#  'across': ['our', 'oceans', 'this'],
#  'land,': ['a'],
#  'nagging': ['fear'],
#  'fear': ['that'],
#  "America's": ['decline', 'birth,'],
#  'decline': ['is'],
#  'inevitable,': ['that'],
#  'next': ['generation'],
#  'lower': ['its', 'its'],
#  'its': ['sights.',
#   'rightful',
#   'cost.',
#   'prudent',
#   'people',
#   'defense.',
#   'role'],
#  'sights.': ['Today'],
#  'Today': ['I'],
#  'say': ['to', 'to', 'we'],
#  'challenges': ['we', 'may'],
#  'face': ['are', 'of'],
#  'real.': ['They'],
#  'They': ['are', 'will', 'will', 'saw', 'understood', 'have', 'have'],
#  'serious,': ['and'],
#  'they': ['are',
#   'packed',
#   'toiled',
#   'fought',
#   'were',
#   'have',
#   'can',
#   'knew',
#   'are',
#   'embody'],
#  'will': ['not',
#   'be',
#   'act',
#   'build',
#   'restore',
#   'harness',
#   'transform',
#   'do.',
#   'end.',
#   'be',
#   'not',
#   'begin',
#   'work',
#   'not',
#   'we',
#   'defeat',
#   'judge',
#   'extend',
#   'define'],
#  'met': ['easily'],
#  'easily': ['or'],
#  'short': ['span'],
#  'span': ['of'],
#  'time.': ['But'],
#  'But': ['know', 'our', 'this', 'those'],
#  'know': ['this,', 'that', 'that', 'that', 'that'],
#  'this,': ['America:'],
#  'America:': ['They'],
#  'met.': ['On'],
#  'On': ['this', 'this'],
#  'day,': ['we', 'we', 'because'],
#  'gather': ['because'],
#  'chosen': ['hope'],
#  'hope': ['over', 'and', 'and'],
#  'over': ['fear,', 'conflict', 'work'],
#  'fear,': ['unity'],
#  'unity': ['of'],
#  'purpose': ['over', 'and'],
#  'conflict': ['and', 'or'],
#  'discord.': ['On'],
#  'come': ['to', 'to', 'to'],
#  'proclaim': ['an'],
#  'an': ['end', 'uncertain', 'icy'],
#  'end': ['to', 'of'],
#  'petty': ['grievances'],
#  'grievances': ['and'],
#  'false': ['promises,', 'the'],
#  'promises,': ['the'],
#  'recriminations': ['and'],
#  'worn-out': ['dogmas'],
#  'dogmas': ['that'],
#  'far': ['too', 'we'],
#  'long': ['have', 'no', 'when'],
#  'strangled': ['our'],
#  'politics.': ['We'],
#  'We': ['remain',
#   'remain',
#   'will',
#   'will',
#   'will',
#   'are',
#   'will',
#   'will',
#   'are',
#   'are',
#   'honor'],
#  'remain': ['a', 'the'],
#  'young': ['nation,'],
#  'nation,': ['but'],
#  'Scripture,': ['the'],
#  'time': ['has', 'has', 'of', 'has'],
#  'set': ['aside'],
#  'aside': ['childish'],
#  'childish': ['things.'],
#  'things.': ['The'],
#  'reaffirm': ['our'],
#  'enduring': ['spirit,', 'convictions.'],
#  'spirit,': ['to', 'so'],
#  'choose': ['our'],
#  'better': ['history,', 'life.'],
#  'history,': ['to', 'but'],
#  'carry': ['forward'],
#  'forward': ['that', 'based'],
#  'precious': ['gift,'],
#  'gift,': ['that'],
#  'noble': ['idea'],
#  'idea': ['passed'],
#  'passed': ['on'],
#  'from': ['generation', 'the', 'the', 'every', 'that'],
#  'generation:': ['the'],
#  'God-given': ['promise'],
#  'promise': ['that', 'of'],
#  'all': ['are', 'are', 'deserve', 'the', 'the', 'to'],
#  'equal,': ['all'],
#  'free,': ['and'],
#  'deserve': ['a'],
#  'chance': ['to'],
#  'pursue': ['their'],
#  'their': ['full',
#   'labor--who',
#   'few',
#   'hands',
#   'government.',
#   'aims',
#   "society's",
#   'hours',
#   'job,'],
#  'full': ['measure'],
#  'measure': ['of'],
#  'happiness.': ['In'],
#  'In': ['reaffirming', 'the'],
#  'reaffirming': ['the'],
#  'greatness': ['of', 'is'],
#  'understand': ['that', 'is'],
#  'never': ['a', 'been'],
#  'given.': ['It'],
#  'It': ['must', 'has', 'is', 'is'],
#  'earned.': ['Our'],
#  'journey': ['has', 'we', 'end;'],
#  'one': ['of', 'common'],
#  'shortcuts': ['or'],
#  'settling': ['for'],
#  'less.': ['It'],
#  'path': ['for', 'toward'],
#  'fainthearted,': ['for'],
#  'who': ['prefer',
#   'question',
#   'suggest',
#   'manage',
#   'are',
#   'seeks',
#   'seek',
#   'seek',
#   'cling',
#   'lie',
#   'would',
#   'we'],
#  'prefer': ['leisure'],
#  'leisure': ['over'],
#  'work': ['or', 'of', 'to', 'tirelessly', 'alongside'],
#  'seek': ['only', 'to', 'a', 'to'],
#  'only': ['the', 'to', 'then', 'the', 'because'],
#  'pleasures': ['of'],
#  'riches': ['and'],
#  'fame.': ['Rather,'],
#  'Rather,': ['it'],
#  'risk-takers,': ['the'],
#  'doers,': ['the'],
#  'makers': ['of'],
#  'things--some': ['celebrated,'],
#  'celebrated,': ['but'],
#  'more': ['often', 'united,', 'the'],
#  'often': ['men'],
#  'men': ['and', 'and', 'and', 'and'],
#  'women': ['obscure', 'struggled', 'can', 'and'],
#  'obscure': ['in'],
#  'labor--who': ['have'],
#  'us': ['up',
#   'together.',
#   'for',
#   'who',
#   'whether',
#   'that',
#   'to',
#   'today,',
#   'all.',
#   'through',
#   'now',
#   'to',
#   'mark',
#   'remember',
#   'brave'],
#  'up': ['the', 'their', 'for'],
#  'long,': ['rugged'],
#  'rugged': ['path'],
#  'toward': ['prosperity'],
#  'freedom.': ['For'],
#  'For': ['us,', 'us,', 'us,', 'everywhere', 'we', 'as'],
#  'packed': ['up'],
#  'few': ['worldly'],
#  'worldly': ['possessions'],
#  'possessions': ['and'],
#  'traveled': ['across'],
#  'oceans': ['in'],
#  'search': ['of'],
#  'life.': ['For', 'They'],
#  'toiled': ['in'],
#  'sweatshops': ['and'],
#  'settled': ['the'],
#  'West,': ['endured', 'know'],
#  'endured': ['the'],
#  'lash': ['of'],
#  'whip,': ['and'],
#  'plowed': ['the'],
#  'Earth.': ['For', 'Our', 'And'],
#  'fought': ['and'],
#  'died': ['in'],
#  'places': ['like'],
#  'like': ['Concord', 'ours'],
#  'Concord': ['and'],
#  'Gettysburg,': ['Normandy'],
#  'Normandy': ['and'],
#  'Khe': ['Sanh.'],
#  'Sanh.': ['Time'],
#  'Time': ['and'],
#  'again,': ['these'],
#  'struggled': ['and'],
#  'sacrificed': ['and'],
#  'worked': ["'til"],
#  "'til": ['their'],
#  'hands': ['were'],
#  'were': ['raw', 'last', 'tested,'],
#  'raw': ['so'],
#  'might': ['live', 'not'],
#  'live': ['a'],
#  'saw': ['America'],
#  'bigger': ['than'],
#  'than': ['the', 'all', 'when', 'they', 'themselves.', 'see', 'giving', '60'],
#  'sum': ['of'],
#  'individual': ['ambitions,'],
#  'ambitions,': ['greater', 'who'],
#  'greater': ['than', 'effort,', 'cooperation', 'than'],
#  'differences': ['of'],
#  'birth': ['or'],
#  'wealth': ['or', 'and'],
#  'faction.': ['This'],
#  'This': ['is', 'is', 'is', 'is'],
#  'continue': ['today.'],
#  'today.': ['We'],
#  'most': ['prosperous,', 'sacred', 'in'],
#  'prosperous,': ['powerful'],
#  'powerful': ['nation'],
#  'nation': ['on', 'and', 'of'],
#  'workers': ['are', 'who'],
#  'productive': ['than'],
#  'when': ['this', 'imagination', 'it', 'the', 'the', 'nothing', 'we'],
#  'began.': ['Our'],
#  'minds': ['are'],
#  'inventive.': ['Our'],
#  'goods': ['and'],
#  'services': ['no'],
#  'needed': ['than'],
#  'last': ['week', 'month', 'year.'],
#  'week': ['or'],
#  'month': ['or'],
#  'year.': ['Our'],
#  'capacity': ['remains'],
#  'remains': ['undiminished.'],
#  'undiminished.': ['But'],
#  'standing': ['pat,'],
#  'pat,': ['of'],
#  'protecting': ['narrow'],
#  'narrow': ['interests'],
#  'interests': ['and'],
#  'putting': ['off'],
#  'off': ['unpleasant'],
#  'unpleasant': ['decisions,'],
#  'decisions,': ['that'],
#  'surely': ['passed.'],
#  'passed.': ['Starting'],
#  'Starting': ['today,'],
#  'today,': ['we', 'from', 'just'],
#  'pick': ['ourselves'],
#  'ourselves': ['up,', 'off,'],
#  'up,': ['dust'],
#  'dust': ['ourselves'],
#  'off,': ['and'],
#  'begin': ['again', 'to'],
#  'again': ['the'],
#  'remaking': ['America.'],
#  'America.': ['For', 'Note:'],
#  'everywhere': ['we'],
#  'look,': ['there'],
#  'there': ['is', 'are', 'is'],
#  'done.': ['The'],
#  'state': ['of'],
#  'calls': ['for', 'on'],
#  'action,': ['bold'],
#  'bold': ['and'],
#  'swift,': ['and'],
#  'act': ['not'],
#  'create': ['new'],
#  'lay': ['a'],
#  'foundation': ['for'],
#  'growth.': ['We'],
#  'build': ['the'],
#  'roads': ['and'],
#  'bridges,': ['the'],
#  'electric': ['grids'],
#  'grids': ['and'],
#  'digital': ['lines'],
#  'lines': ['that', 'of'],
#  'feed': ['our', 'hungry'],
#  'commerce': ['and'],
#  'bind': ['us'],
#  'together.': ['We'],
#  'restore': ['science', 'the'],
#  'science': ['to'],
#  'rightful': ['place'],
#  'place': ['and'],
#  'wield': ["technology's"],
#  "technology's": ['wonders'],
#  'wonders': ['to'],
#  'raise': ['health'],
#  "care's": ['quality'],
#  'quality': ['and'],
#  'cost.': ['We'],
#  'harness': ['the'],
#  'sun': ['and'],
#  'winds': ['and'],
#  'soil': ['to'],
#  'fuel': ['our'],
#  'cars': ['and'],
#  'run': ['our'],
#  'factories.': ['And'],
#  'transform': ['our'],
#  'colleges': ['and'],
#  'universities': ['to'],
#  'meet': ['the', 'those', 'them', '[it]."'],
#  'demands': ['of'],
#  'All': ['this', 'this'],
#  'can': ['do.',
#   'achieve',
#   'afford,',
#   'we',
#   'spin',
#   'scarcely',
#   'meet',
#   'build,',
#   'no',
#   'we',
#   'do',
#   'join',
#   'now'],
#  'do.': ['All', 'Now,'],
#  'Now,': ['there'],
#  'some': ['who'],
#  'question': ['the', 'we', 'before'],
#  'scale': ['of'],
#  'suggest': ['that'],
#  'system': ['cannot'],
#  'cannot': ['tolerate', 'prosper', 'protect', 'be', 'outlast', 'help'],
#  'tolerate': ['too'],
#  'many': ['big'],
#  'big': ['plans.', 'or'],
#  'plans.': ['Their'],
#  'Their': ['memories'],
#  'memories': ['are'],
#  'short,': ['for'],
#  'forgotten': ['what'],
#  'what': ['this', 'free', 'you', 'you', 'storms'],
#  'country': ['has'],
#  'already': ['done,'],
#  'done,': ['what'],
#  'free': ['men'],
#  'achieve': ['when'],
#  'imagination': ['is'],
#  'joined': ['to'],
#  'common': ['purpose', 'good.', 'defense,', 'humanity', 'danger,', 'dangers,'],
#  'necessity': ['to'],
#  'courage.': ['What'],
#  'What': ['the', 'is', 'is'],
#  'cynics': ['fail'],
#  'ground': ['has'],
#  'shifted': ['beneath'],
#  'beneath': ['them,'],
#  'them,': ['that'],
#  'stale': ['political'],
#  'political': ['arguments'],
#  'arguments': ['that'],
#  'consumed': ['us'],
#  'longer': ['apply.', 'afford'],
#  'apply.': ['The'],
#  'ask': ['today'],
#  'whether': ['our', 'it', 'it', 'the'],
#  'Government': ['is', 'can'],
#  'small,': ['but'],
#  'works;': ['whether'],
#  'helps': ['families'],
#  'families': ['find'],
#  'find': ['jobs', 'meaning'],
#  'decent': ['wage,'],
#  'wage,': ['care'],
#  'afford,': ['a'],
#  'retirement': ['that'],
#  'dignified.': ['Where'],
#  'Where': ['the', 'the'],
#  'answer': ['is', 'is'],
#  'yes,': ['we'],
#  'intend': ['to'],
#  'move': ['forward.'],
#  'forward.': ['Where'],
#  'no,': ['programs'],
#  'programs': ['will'],
#  'end.': ['And'],
#  'manage': ['the'],
#  "public's": ['dollars'],
#  'dollars': ['will'],
#  'held': ['to'],
#  'account': ['to'],
#  'spend': ['wisely,'],
#  'wisely,': ['reform'],
#  'reform': ['bad'],
#  'bad': ['habits,'],
#  'habits,': ['and'],
#  'do': ['our', 'as', 'and', 'not'],
#  'business': ['in'],
#  'light': ['of', 'the'],
#  'then': ['can', 'is'],
#  'vital': ['trust'],
#  'between': ['a', 'our', 'nations.'],
#  'government.': ['Nor'],
#  'Nor': ['is'],
#  'market': ['is', 'can'],
#  'force': ['for', 'of', 'of'],
#  'good': ['or'],
#  'ill.': ['Its'],
#  'Its': ['power'],
#  'power': ['to', 'alone', 'grows', 'through'],
#  'generate': ['wealth'],
#  'expand': ['freedom'],
#  'freedom': ['is', 'and'],
#  'unmatched.': ['But'],
#  'reminded': ['us'],
#  'without': ['a', 'regard'],
#  'watchful': ['eye,'],
#  'eye,': ['the'],
#  'spin': ['out'],
#  'out': ['of', 'of'],
#  'control.': ['The'],
#  'prosper': ['long'],
#  'favors': ['only'],
#  'prosperous.': ['The'],
#  'success': ['of', 'depends--honesty'],
#  'always': ['depended'],
#  'depended': ['not'],
#  'just': ['on', 'with', 'as'],
#  'size': ['of'],
#  'gross': ['domestic'],
#  'domestic': ['product,'],
#  'product,': ['but'],
#  'reach': ['of'],
#  'prosperity,': ['on'],
#  'ability': ['to'],
#  'extend': ['opportunity', 'a'],
#  'opportunity': ['to'],
#  'willing': ['heart,', 'to'],
#  'heart,': ['not'],
#  'charity,': ['but'],
#  'surest': ['route'],
#  'route': ['to'],
#  'good.': ['As'],
#  'As': ['for', 'we'],
#  'defense,': ['we'],
#  'reject': ['as'],
#  'choice': ['between'],
#  'safety': ['and'],
#  'ideals.': ['Our'],
#  'Founding': ['Fathers,'],
#  'Fathers,': ['faced'],
#  'faced': ['with', 'down'],
#  'perils': ['that'],
#  'scarcely': ['imagine,'],
#  'imagine,': ['drafted'],
#  'drafted': ['a'],
#  'charter': ['to', 'expanded'],
#  'assure': ['the'],
#  'rule': ['of'],
#  'law': ['and'],
#  'rights': ['of'],
#  'man,': ['a', 'woman,'],
#  'expanded': ['by'],
#  'blood': ['of'],
#  'generations.': ['Those', 'Thank'],
#  'Those': ['ideals'],
#  'world,': ['and', 'we'],
#  'give': ['them'],
#  'them': ['up', 'not', 'may'],
#  "expedience's": ['sake.'],
#  'sake.': ['And'],
#  'other': ['peoples'],
#  'peoples': ['and'],
#  'governments': ['who'],
#  'watching': ['today,'],
#  'grandest': ['capitals'],
#  'capitals': ['to'],
#  'small': ['village', 'band'],
#  'village': ['where'],
#  'where': ['my'],
#  'my': ['father'],
#  'father': ['was', 'less'],
#  'was': ['born,', 'abandoned.', 'advancing.', 'stained', 'most', 'released'],
#  'born,': ['know'],
#  'friend': ['of', 'lose'],
#  'woman,': ['and'],
#  'child': ['who'],
#  'seeks': ['a'],
#  'future': ['of', 'world', 'generations.'],
#  'peace': ['and', 'in'],
#  'dignity,': ['and'],
#  'ready': ['to'],
#  'lead': ['once'],
#  'once': ['more.', 'more,', 'more'],
#  'more.': ['Recall'],
#  'Recall': ['that'],
#  'earlier': ['generations'],
#  'generations': ['faced'],
#  'down': ['fascism'],
#  'fascism': ['and'],
#  'communism': ['not'],
#  'missiles': ['and'],
#  'tanks': ['but'],
#  'sturdy': ['alliances'],
#  'alliances': ['and'],
#  'convictions.': ['They'],
#  'understood': ['that'],
#  'alone': ['cannot'],
#  'protect': ['us,'],
#  'nor': ['does', 'will', 'can', 'did'],
#  'does': ['it'],
#  'entitle': ['us'],
#  'please.': ['Instead,'],
#  'Instead,': ['they'],
#  'knew': ['that'],
#  'grows': ['through', 'smaller,'],
#  'through': ['its', 'corruption', 'the', 'our'],
#  'prudent': ['use.'],
#  'use.': ['Our'],
#  'security': ['emanates'],
#  'emanates': ['from'],
#  'justness': ['of'],
#  'cause,': ['the'],
#  'example,': ['the'],
#  'tempering': ['qualities'],
#  'qualities': ['of'],
#  'humility': ['and'],
#  'restraint.': ['We'],
#  'keepers': ['of'],
#  'legacy.': ['Guided'],
#  'Guided': ['by'],
#  'principles': ['once'],
#  'more,': ['we'],
#  'threats': ['that'],
#  'demand': ['even'],
#  'even': ['greater', 'greater'],
#  'effort,': ['even'],
#  'understanding': ['between'],
#  'nations.': ['We'],
#  'responsibly': ['leave'],
#  'leave': ['Iraq'],
#  'Iraq': ['to'],
#  'forge': ['a'],
#  'hard-earned': ['peace'],
#  'Afghanistan.': ['With'],
#  'With': ['old', 'hope'],
#  'old': ['friends', 'hatreds'],
#  'friends': ['and'],
#  'former': ['foes,'],
#  'foes,': ['we'],
#  'tirelessly': ['to'],
#  'lessen': ['the'],
#  'nuclear': ['threat'],
#  'threat': ['and'],
#  'roll': ['back'],
#  'back': ['the'],
#  'specter': ['of'],
#  'warming': ['planet.'],
#  'apologize': ['for'],
#  'way': ['of', 'forward'],
#  'life,': ['nor'],
#  'waver': ['in'],
#  'defense.': ['And'],
#  'advance': ['their'],
#  'aims': ['by'],
#  'inducing': ['terror'],
#  'terror': ['and'],
#  'slaughtering': ['innocents,'],
#  'innocents,': ['we'],
#  'spirit': ['is', 'of', 'that'],
#  'stronger': ['and', 'and'],
#  'broken.': ['You'],
#  'You': ['cannot'],
#  'outlast': ['us,'],
#  'defeat': ['you.'],
#  'you.': ['For', 'God'],
#  'patchwork': ['heritage'],
#  'heritage': ['is'],
#  'strength,': ['not'],
#  'weakness.': ['We'],
#  'Christians': ['and'],
#  'Muslims,': ['Jews'],
#  'Jews': ['and'],
#  'Hindus': ['and'],
#  'nonbelievers.': ['We'],
#  'shaped': ['by'],
#  'language': ['and'],
#  'culture,': ['drawn'],
#  'drawn': ['from'],
#  'tasted': ['the'],
#  'bitter': ['swill'],
#  'swill': ['of'],
#  'civil': ['war'],
#  'segregation': ['and'],
#  'emerged': ['from'],
#  'dark': ['chapter'],
#  'chapter': ['stronger'],
#  'united,': ['we'],
#  'help': ['but'],
#  'believe': ['that'],
#  'hatreds': ['shall'],
#  'shall': ['someday', 'soon', 'reveal'],
#  'someday': ['pass,'],
#  'pass,': ['that'],
#  'tribe': ['shall'],
#  'soon': ['dissolve;'],
#  'dissolve;': ['that'],
#  'world': ['grows', 'has', '.'],
#  'smaller,': ['our'],
#  'humanity': ['shall'],
#  'reveal': ['itself,'],
#  'itself,': ['and'],
#  'play': ['its'],
#  'role': ['in'],
#  'ushering': ['in'],
#  'era': ['of', 'of'],
#  'To': ['the', 'those', 'those', 'the'],
#  'Muslim': ['world,'],
#  'based': ['on'],
#  'mutual': ['interest', 'respect.'],
#  'interest': ['and'],
#  'respect.': ['To'],
#  'leaders': ['around'],
#  'around': ['the'],
#  'globe': ['who'],
#  'sow': ['conflict'],
#  'blame': ['their'],
#  "society's": ['ills'],
#  'ills': ['on'],
#  'your': ['people', 'fist.', 'farms'],
#  'judge': ['you'],
#  'build,': ['not'],
#  'destroy.': ['To'],
#  'cling': ['to'],
#  'corruption': ['and'],
#  'deceit': ['and'],
#  'silencing': ['of'],
#  'dissent,': ['know'],
#  'wrong': ['side'],
#  'side': ['of'],
#  'hand': ['if'],
#  'if': ['you'],
#  'unclench': ['your'],
#  'fist.': ['To'],
#  'poor': ['nations,'],
#  'nations,': ['we'],
#  'pledge': ['to'],
#  'alongside': ['you'],
#  'farms': ['flourish'],
#  'flourish': ['and'],
#  'let': ['clean', 'us', 'us', 'us', 'this'],
#  'clean': ['waters'],
#  'flow,': ['to'],
#  'nourish': ['starved'],
#  'starved': ['bodies'],
#  'bodies': ['and'],
#  'hungry': ['minds.'],
#  'minds.': ['And'],
#  'nations': ['like'],
#  'ours': ['that'],
#  'enjoy': ['relative'],
#  'relative': ['plenty,'],
#  'plenty,': ['we'],
#  'afford': ['indifference'],
#  'indifference': ['to'],
#  'suffering': ['outside'],
#  'outside': ['our'],
#  'borders,': ['nor'],
#  'consume': ['the'],
#  "world's": ['resources'],
#  'resources': ['without'],
#  'regard': ['to'],
#  'effect,': ['for'],
#  'changed,': ['and'],
#  'change': ['with'],
#  'it.': ['As'],
#  'consider': ['the'],
#  'road': ['that'],
#  'unfolds': ['before'],
#  'remember': ['with', 'these'],
#  'humble': ['gratitude'],
#  'gratitude': ['those'],
#  'brave': ['Americans', 'once'],
#  'who,': ['at'],
#  'very': ['hour,'],
#  'hour,': ['patrol'],
#  'patrol': ['far-off'],
#  'far-off': ['deserts'],
#  'deserts': ['and'],
#  'distant': ['mountains.'],
#  'mountains.': ['They'],
#  'something': ['to', 'greater'],
#  'tell': ['us'],
#  'fallen': ['heroes'],
#  'heroes': ['who'],
#  'lie': ['in'],
#  'Arlington': ['whisper'],
#  'whisper': ['through'],
#  'ages.': ['We'],
#  'honor': ['them'],
#  'guardians': ['of'],
#  'liberty,': ['but'],
#  'embody': ['the'],
#  'service,': ['a'],
#  'willingness': ['to', 'to'],
#  'meaning': ['in', 'of'],
#  'themselves.': ['And'],
#  'yet': ['at'],
#  'moment,': ['a'],
#  'moment': ['that', 'when'],
#  'define': ['a'],
#  'generation,': ['it'],
#  'precisely': ['this'],
#  'inhabit': ['us'],
#  'all.': ['For'],
#  'much': ['as'],
#  'do,': ['it'],
#  'ultimately': ['the'],
#  'faith': ['and', 'can'],
#  'determination': ['of'],
#  'American': ['people', 'that', 'Presidency'],
#  'upon': ['which', 'which', 'us,'],
#  'which': ['this', 'sees', 'we', 'our'],
#  'relies.': ['It'],
#  'kindness': ['to'],
#  'take': ['in', 'a'],
#  'stranger': ['when'],
#  'levees': ['break,'],
#  'break,': ['the'],
#  'selflessness': ['of'],
#  'would': ['rather'],
#  'rather': ['cut'],
#  'cut': ['their'],
#  'hours': ['than'],
#  'see': ['a'],
#  'lose': ['their'],
#  'job,': ['which'],
#  'sees': ['us'],
#  'darkest': ['hours.'],
#  'hours.': ['It'],
#  "firefighter's": ['courage'],
#  'courage': ['to', 'and'],
#  'storm': ['a'],
#  'stairway': ['filled'],
#  'filled': ['with'],
#  'smoke,': ['but'],
#  "parent's": ['willingness'],
#  'nurture': ['a'],
#  'child,': ['that'],
#  'finally': ['decides'],
#  'decides': ['our'],
#  'fate.': ['Our'],
#  'may': ['be', 'be', 'come.'],
#  'new.': ['The', 'But'],
#  'instruments': ['with'],
#  'values': ['upon'],
#  'depends--honesty': ['and'],
#  'work,': ['courage'],
#  'fair': ['play,'],
#  'play,': ['tolerance'],
#  'tolerance': ['and'],
#  'curiosity,': ['loyalty'],
#  'loyalty': ['and'],
#  'patriotism--these': ['things'],
#  'things': ['are', 'are'],
#  'old.': ['These'],
#  'true.': ['They'],
#  'quiet': ['force'],
#  'progress': ['throughout'],
#  'history.': ['What'],
#  'demanded': ['then'],
#  'return': ['to'],
#  'truths.': ['What'],
#  'required': ['of'],
#  'responsibility,': ['a'],
#  'recognition': ['on'],
#  'duties': ['to'],
#  'ourselves,': ['our'],
#  'world.': ['Duties'],
#  'Duties': ['that'],
#  'grudgingly': ['accept'],
#  'accept': ['but,'],
#  'but,': ['rather,'],
#  'rather,': ['seize'],
#  'seize': ['gladly,'],
#  'gladly,': ['firm'],
#  'firm': ['in'],
#  'knowledge': ['that', 'that'],
#  'nothing': ['so', 'but'],
#  'satisfying': ['to'],
#  'defining': ['of'],
#  'character,': ['than'],
#  'giving': ['our'],
#  'difficult': ['task.'],
#  'task.': ['This'],
#  'price': ['and'],
#  'citizenship.': ['This'],
#  'source': ['of'],
#  'confidence,': ['the'],
#  'God': ['calls', 'bless', 'bless'],
#  'shape': ['an'],
#  'uncertain': ['destiny.'],
#  'destiny.': ['This'],
#  'liberty': ['and'],
#  'creed;': ['why'],
#  'why': ['men', 'a'],
#  'children': ['of', 'that'],
#  'race': ['and'],
#  'join': ['in'],
#  'celebration': ['across'],
#  'magnificent': ['Mall,'],
#  'Mall,': ['and'],
#  'man': ['whose'],
#  'whose': ['father'],
#  '60': ['years'],
#  'years': ['ago'],
#  'ago': ['might'],
#  'served': ['at'],
#  'local': ['restaurant'],
#  'restaurant': ['can'],
#  'sacred': ['oath.'],
#  'mark': ['this'],
#  'remembrance': ['of'],
#  'how': ['far'],
#  'traveled.': ['In'],
#  'year': ['of'],
#  'birth,': ['in'],
#  'coldest': ['of'],
#  'months,': ['a'],
#  'band': ['of'],
#  'patriots': ['huddled'],
#  'huddled': ['by'],
#  'dying': ['campfires'],
#  'campfires': ['on'],
#  'shores': ['of'],
#  'icy': ['river.', 'currents'],
#  'river.': ['The'],
#  'Capital': ['was'],
#  'abandoned.': ['The'],
#  'enemy': ['was'],
#  'advancing.': ['The'],
#  'snow': ['was'],
#  'stained': ['with'],
#  'blood.': ['At'],
#  'outcome': ['of'],
#  'Revolution': ['was'],
#  'doubt,': ['the'],
#  'Father': ['of'],
#  'ordered': ['these'],
#  'read': ['to'],
#  'people:': ['"Let'],
#  '"Let': ['it'],
#  'told': ['to'],
#  '.': ['.', '.', 'that', '.', '.', 'that'],
#  'depth': ['of'],
#  'winter,': ['when'],
#  'virtue': ['could'],
#  'could': ['survive'],
#  'survive': ['.'],
#  'city': ['and'],
#  'country,': ['alarmed'],
#  'alarmed': ['at'],
#  'danger,': ['came'],
#  'came': ['forth'],
#  'forth': ['to', 'that'],
#  '[it]."': ['America,'],
#  'America,': ['in'],
#  'dangers,': ['in'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# Create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(obama_dict)
# Out:
# 'Job, which this we will restore science to power to you can now is the.'

# %% [markdown]
# ## Next Step
# The next step on improving text generation is to build a deep learning model that can generate well thoughtout sentences that actually make sense.
